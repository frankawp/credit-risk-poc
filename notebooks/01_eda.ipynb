# %% [markdown]
# # Home Credit Anti-Fraud EDA
#
# 运行 `PYTHONPATH=src python3 -m anti_fraud.pipelines.run_eda` 之后，在此 Notebook 中查看主要产物。

# %%
from pathlib import Path
import pandas as pd

report_dir = Path('../outputs/reports')
pd.read_csv(report_dir / 'table_overview.csv')

# %%
pd.read_csv(report_dir / 'customer_density.csv')

# %%
Path(report_dir / 'eda_summary.md').read_text()
